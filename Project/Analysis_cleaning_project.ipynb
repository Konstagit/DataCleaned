# %%
import pandas as pd
import numpy as np

# %%
melb_df=pd.read_csv('data\melb_data_fe.csv')

# %%
melb_df.head()
# Out:
#        Suburb  Rooms   Type      Price Method SellerG        Date  Distance  \
# 0  Abbotsford      2  house  1480000.0      S  Biggin  2016-03-12       2.5
# 1  Abbotsford      2  house  1035000.0      S  Biggin  2016-04-02       2.5
# 2  Abbotsford      3  house  1465000.0     SP  Biggin  2017-04-03       2.5
# 3  Abbotsford      3  house   850000.0     PI  Biggin  2017-04-03       2.5
# 4  Abbotsford      4  house  1600000.0     VB  Nelson  2016-04-06       2.5
#
#    Postcode  Bedroom  ...  Longtitude             Regionname  Propertycount  \
# 0      3067        2  ...    144.9984  Northern Metropolitan           4019
# 1      3067        2  ...    144.9934  Northern Metropolitan           4019
# 2      3067        3  ...    144.9944  Northern Metropolitan           4019
# 3      3067        3  ...    144.9969  Northern Metropolitan           4019
# 4      3067        3  ...    144.9941  Northern Metropolitan           4019
#
# ...

# %%
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  object
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  object
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  object
#  5   SellerG          13580 non-null  object
#  6   Date             13580 non-null  object
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  object
#  15  Lattitude        13580 non-null  float64
# ...

# %%
melb_df['Date']=pd.to_datetime(melb_df['Date'], format='%Y-%m-%d')

# %%
melb_df['Date'].dt.quarter.count()
# Out:
# 13580

# %%
unique_list=[]
for col in melb_df.columns:
    item=(col,melb_df[col].nunique(),melb_df[col].dtypes)
    unique_list.append(item)
unique_df=pd.DataFrame(unique_list,
                       columns = ['Column_Name', 'Num_Unique', 'Type']).sort_values(by='Num_Unique',ignore_index=True)

# %%
display(unique_df)
# Out:
#         Column_Name  Num_Unique            Type
# 0           Weekend           2           int64
# 1              Type           3          object
# 2            Method           5          object
# 3       WeekdaySale           7           int64
# 4        Regionname           8          object
# 5             Rooms           9           int64
# 6          Bathroom           9           int64
# 7               Car          11           int64
# 8        StreetType          11          object
# 9         MonthSale          12           int64
# 10          Bedroom          12           int64
# 11      CouncilArea          33          object
# 12          SellerG          50          object
# 13             Date          58  datetime64[ns]
# 14           Suburb         120          object
# 15      AgeBuilding         152           int64
# 16         Postcode         198           int64
# 17         Distance         202         float64
# 18    Propertycount         311           int64
# ...

# %%
list_to_exclude=['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car']
max_val_counts=150
for col in melb_df.columns:
    if melb_df[col].nunique() < max_val_counts and col not in list_to_exclude:
        melb_df[col]=melb_df[col].astype('category')
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %%
display((melb_df.columns[melb_df.dtypes=='category']))
# Out:
# Index(['Suburb', 'Type', 'Method', 'SellerG', 'CouncilArea', 'Regionname',
#        'MonthSale', 'WeekdaySale', 'StreetType', 'Weekend'],
#       dtype='object')

# %%
melb_df2=melb_df.copy()

# %%
melb_df2.sort_values(by='AreaRatio',ascending=False, ignore_index=True,inplace=True)

# %%
melb_df2.head()
# Out:
#            Suburb  Rooms  Type     Price Method   SellerG       Date  \
# 0  Brunswick East      2  unit  390000.0     PI     other 2017-03-18
# 1          Elwood      2  unit  590000.0     PI   McGrath 2016-10-09
# 2          Elwood      2  unit  550000.0      S     other 2016-06-08
# 3          Elwood      1  unit  357000.0      S  Chisholm 2016-07-05
# 4          Elwood      2  unit  685000.0     PI  Marshall 2016-07-05
#
#    Distance  Postcode  Bedroom  ...  Longtitude             Regionname  \
# 0       4.5      3057        2  ...    144.9780  Northern Metropolitan
# 1       7.7      3184        2  ...    144.9853  Southern Metropolitan
# 2       7.7      3184        2  ...    144.9855  Southern Metropolitan
# 3       7.7      3184        1  ...    144.9885  Southern Metropolitan
# 4       7.7      3184        2  ...    144.9918  Southern Metropolitan
#
#    Propertycount  MeanRoomsSquare AreaRatio  MonthSale  AgeBuilding  \
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
melb_df2.loc[1550:1560,:]
# Out:
#                Suburb  Rooms   Type      Price Method        SellerG  \
# 1550         Brighton      3   unit  1250000.0      S       Marshall
# 1551            other      2   unit   650000.0     VB        McGrath
# 1552         Brighton      2   unit   610000.0      S             RT
# 1553            other      2   unit   350000.0     SP           Gary
# 1554         Brighton      3   unit  1005000.0     SP  hockingstuart
# 1555  Caulfield North      1   unit   350000.0     PI  hockingstuart
# 1556  Caulfield North      2   unit   665000.0      S       Woodards
# 1557       Cheltenham      2   unit   850000.0      S            C21
# 1558      Elsternwick      2  house   716000.0      S  hockingstuart
# 1559           Ormond      2   unit   485000.0     SP           Gary
# 1560         Brighton      3  house  1900000.0      S       Marshall
#
#            Date  Distance  Postcode  Bedroom  Bathroom  Car  Landsize  \
# ...

# %%
mask=(melb_df2['Type']=='townhouse') & ( melb_df2['Rooms']>2)

# %%
melb_df2[mask].sort_values(by=['Rooms', 'MeanRoomsSquare'],
    ascending=[True, False],
    ignore_index=True).iloc[17:22,:]
# Out:
#            Suburb  Rooms       Type      Price Method SellerG       Date  \
# 17          other      3  townhouse   970000.0     PI   Barry 2016-09-24
# 18  Brighton East      3  townhouse  1300000.0     PI  Buxton 2016-09-17
# 19         Toorak      3  townhouse  2700000.0     VB     Kay 2016-12-06
# 20         Toorak      3  townhouse  1550000.0     VB     Kay 2016-10-15
# 21   Airport West      3  townhouse   856000.0      S   Barry 2017-05-27
#
#     Distance  Postcode  Bedroom  Bathroom  Car  Landsize  BuildingArea  \
# 17       9.8      3040        3         2    2     356.0         223.0
# 18      10.7      3187        3         2    2     337.0         222.0
# 19       4.6      3142        3         2    2     294.0         220.0
# 20       4.6      3142        3         2    2     117.0         214.0
# 21      10.4      3042        3         2    1     300.0         212.0
#
#       CouncilArea  Lattitude  Longtitude             Regionname  \
# ...

# %%
pd.reset_option('display.max_columns')

# %%
melb_df.groupby(by='Type').mean(numeric_only=True)
# Out:
# C:\Users\donru\AppData\Local\Temp\ipykernel_24120\2774055988.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(by='Type').mean(numeric_only=True)
#               Rooms         Price   Distance     Postcode   Bedroom  Bathroom  \
# Type
# house      3.260874  1.242665e+06  10.979479  3104.080643  3.229336  1.613822
# townhouse  2.837522  9.337351e+05   9.851346  3100.777379  2.814183  1.809695
# unit       1.963871  6.051275e+05   7.607391  3110.797481  1.966523  1.183295
#
#                 Car    Landsize  BuildingArea  Lattitude  Longtitude  \
# Type
# house      1.772674  617.181924    152.162553 -37.803795  144.994700
# townhouse  1.555655  279.606822    134.649710 -37.815782  144.996489
# unit       1.128936  477.314219    102.235863 -37.823710  144.996363
#
# ...

# %%
melb_df.groupby('Type')['Price'].mean()
# Out:
# C:\Users\donru\AppData\Local\Temp\ipykernel_24120\2328732824.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('Type')['Price'].mean()
# Type
# house        1.242665e+06
# townhouse    9.337351e+05
# unit         6.051275e+05
# Name: Price, dtype: float64

# %%
melb_df.groupby('Regionname')['Distance'].min().sort_values(ascending=False)
# Out:
# C:\Users\donru\AppData\Local\Temp\ipykernel_24120\3783769093.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('Regionname')['Distance'].min().sort_values(ascending=False)
# Regionname
# Western Victoria              29.8
# Eastern Victoria              25.2
# Northern Victoria             21.8
# South-Eastern Metropolitan    14.7
# Eastern Metropolitan           7.8
# Western Metropolitan           4.3
# Southern Metropolitan          0.7
# Northern Metropolitan          0.0
# Name: Distance, dtype: float64

# %%
melb_df.groupby('MonthSale')['Price'].agg(
    ['count','mean','max']
).sort_values(by='count',ascending=False)
# Out:
# C:\Users\donru\AppData\Local\Temp\ipykernel_24120\1979431274.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('MonthSale')['Price'].agg(
#            count          mean        max
# MonthSale
# 8           1850  1.056371e+06  6500000.0
# 7           1835  9.314698e+05  9000000.0
# 5           1644  1.097807e+06  8000000.0
# 6           1469  1.068981e+06  7650000.0
# 3           1408  1.146762e+06  5600000.0
# 4           1246  1.050479e+06  5500000.0
# 9           1188  1.126349e+06  6400000.0
# 10           854  1.135970e+06  6250000.0
# 11           750  1.142503e+06  5050000.0
# 12           725  1.144737e+06  5700000.0
# 2            333  1.169051e+06  4735000.0
# 1            278  9.397921e+05  5200000.0

# %%
melb_df.groupby('MonthSale')['Price'].agg('describe')
# Out:
# C:\Users\donru\AppData\Local\Temp\ipykernel_24120\701566850.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('MonthSale')['Price'].agg('describe')
#             count          mean            std       min       25%        50%  \
# MonthSale
# 1           278.0  9.397921e+05  577668.924214  170000.0  570500.0   795000.0
# 2           333.0  1.169051e+06  671564.357417  131000.0  710000.0  1020000.0
# 3          1408.0  1.146762e+06  709573.596867   85000.0  680000.0   945000.0
# 4          1246.0  1.050479e+06  591892.902979  145000.0  655000.0   905500.0
# 5          1644.0  1.097807e+06  668492.867996  145000.0  650000.0   905000.0
# 6          1469.0  1.068981e+06  606010.069052  222000.0  660000.0   900000.0
# ...

# %%
melb_df.groupby('Regionname')['SellerG'].agg(
    ['nunique',set]
)
# Out:
# C:\Users\donru\AppData\Local\Temp\ipykernel_24120\2336078514.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('Regionname')['SellerG'].agg(
#                             nunique  \
# Regionname
# Eastern Metropolitan             26
# Eastern Victoria                 11
# Northern Metropolitan            40
# Northern Victoria                11
# South-Eastern Metropolitan       25
# Southern Metropolitan            38
# Western Metropolitan             34
# Western Victoria                  6
#
#                                                                           set
# Regionname
# Eastern Metropolitan        {Kay, Barry, Nelson, Biggin, Noel, Purplebrick...
# Eastern Victoria            {Harcourts, O'Brien, Barry, hockingstuart, Evi...
# ...

# %%
melb_df.groupby('Rooms')['Price'].agg('describe')
# Out:
#         count          mean           std        min        25%        50%  \
# Rooms
# 1       681.0  4.338245e+05  2.249857e+05    85000.0   325000.0   385000.0
# 2      3648.0  7.750812e+05  3.561259e+05   190000.0   535000.0   690000.0
# 3      5881.0  1.076081e+06  5.021061e+05   283000.0   725000.0   950000.0
# 4      2688.0  1.445282e+06  7.474872e+05   131000.0   902000.0  1285000.0
# 5       596.0  1.870260e+06  9.823493e+05   355000.0  1150000.0  1660000.0
# 6        67.0  1.849366e+06  1.094247e+06   506000.0  1167500.0  1800000.0
# 7        10.0  1.920700e+06  9.476201e+05  1005000.0  1312500.0  1496000.0
# 8         8.0  1.602750e+06  8.306264e+05   741000.0   853250.0  1515000.0
# 10        1.0  9.000000e+05           NaN   900000.0   900000.0   900000.0
#
#              75%        max
# Rooms
# 1       460000.0  2450000.0
# 2       912625.0  4800000.0
# 3      1320000.0  9000000.0
# 4      1786250.0  7650000.0
# 5      2400000.0  8000000.0
# ...

# %%
melb_df.groupby('Regionname')['Lattitude'].agg('describe')
# Out:
# C:\Users\donru\AppData\Local\Temp\ipykernel_24120\1267335943.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('Regionname')['Lattitude'].agg('describe')
#                              count       mean       std       min        25%  \
# Regionname
# Eastern Metropolitan        1471.0 -37.788820  0.047890 -37.90383 -37.823185
# Eastern Victoria              53.0 -37.959292  0.147067 -38.16439 -38.070540
# Northern Metropolitan       3890.0 -37.747258  0.049639 -37.93940 -37.785100
# Northern Victoria             41.0 -37.599620  0.084455 -37.68503 -37.672770
# South-Eastern Metropolitan   450.0 -37.993727  0.073411 -38.18255 -38.028280
# Southern Metropolitan       4695.0 -37.866981  0.043080 -37.99035 -37.901200
# ...

# %%
melb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %%
filteredmelb_df = melb_df[(melb_df['Date']>='2017-05-01') & (melb_df['Date']<= '2017-09-01')]

# %%
filteredmelb_df.groupby('SellerG')['Price'].sum().sort_values()
# Out:
# C:\Users\donru\AppData\Local\Temp\ipykernel_24120\1939051575.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   filteredmelb_df.groupby('SellerG')['Price'].sum().sort_values()
# SellerG
# LITTLE             2742000.0
# Cayzer             4439000.0
# Burnham            4550500.0
# Moonee             7328000.0
# Thomson            8332000.0
# Bells              8656000.0
# Alexkarbon        10985000.0
# McDonald          14637500.0
# Rendina           15422276.0
# Nick              16890000.0
# Douglas           18341000.0
# Buckingham        19033000.0
# C21               19515000.0
# Eview             19791500.0
# Collins           20217000.0
# Philip            22051800.0
# Chisholm          23225000.0
# Williams          23297000.0
# Love              23365500.0
# ...

# %%
melb_df.groupby(['Rooms','Type'],)['Price'].mean().unstack()
# Out:
# C:\Users\donru\AppData\Local\Temp\ipykernel_24120\17459025.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(['Rooms','Type'],)['Price'].mean().unstack()
# Type          house     townhouse          unit
# Rooms
# 1      8.668655e+05  5.927045e+05  3.899289e+05
# 2      1.017238e+06  7.101585e+05  6.104905e+05
# 3      1.109233e+06  9.847087e+05  8.505963e+05
# 4      1.462283e+06  1.217092e+06  1.037476e+06
# 5      1.877327e+06  1.035000e+06           NaN
# 6      1.869508e+06           NaN  5.200000e+05
# 7      1.920700e+06           NaN           NaN
# 8      1.510286e+06           NaN  2.250000e+06
# 10     9.000000e+05           NaN           NaN

# %%
melb_df.pivot_table(values='Price',
                    index = 'Rooms',
                    columns = 'Type',
                    fill_value=0).round()
# Out:
# Type       house  townhouse       unit
# Rooms
# 1       866866.0   592705.0   389929.0
# 2      1017238.0   710158.0   610491.0
# 3      1109233.0   984709.0   850596.0
# 4      1462283.0  1217092.0  1037476.0
# 5      1877327.0  1035000.0        0.0
# 6      1869508.0        0.0   520000.0
# 7      1920700.0        0.0        0.0
# 8      1510286.0        0.0  2250000.0
# 10      900000.0        0.0        0.0

# %%
melb_df.pivot_table(values='Price',
                    index = 'Regionname',
                    columns = 'Weekend',
                    fill_value = 0,
                    aggfunc='count')
# Out:
# Weekend                        0     1
# Regionname
# Eastern Metropolitan         447  1024
# Eastern Victoria              13    40
# Northern Metropolitan       1258  2632
# Northern Victoria             11    30
# South-Eastern Metropolitan   123   327
# Southern Metropolitan       1534  3161
# Western Metropolitan         960  1988
# Western Victoria               8    24

# %%
melb_df.pivot_table(values='Landsize',
                    index = 'Regionname',
                    columns = 'Type',
                    fill_value = 0,
                    aggfunc=['median','mean'])
# Out:
#                            median                          mean              \
# Type                        house townhouse   unit        house   townhouse
# Regionname
# Eastern Metropolitan        674.0     233.5  203.0   717.422847  269.440678
# Eastern Victoria            843.0       0.0  230.0  3108.960000    0.000000
# Northern Metropolitan       459.5     134.0    0.0   619.249092  317.325733
# Northern Victoria           724.0       0.0    0.0  3355.463415    0.000000
# South-Eastern Metropolitan  630.5     240.0  199.0   664.306701  212.160000
# Southern Metropolitan       586.0     246.0    0.0   569.643881  278.858824
# Western Metropolitan        531.0     198.0   62.0   507.883406  244.560669
# Western Victoria            599.5       0.0    0.0   655.500000    0.000000
#
#
# Type                              unit
# Regionname
# Eastern Metropolitan        330.444444
# Eastern Victoria            295.333333
# Northern Metropolitan       495.026538
# ...

# %%
melb_df.pivot_table(
    values='Price',
    index=['Method','Type'],
    columns='Regionname',
    aggfunc='median',
    fill_value=0
)
# Out:
# Regionname        Eastern Metropolitan  Eastern Victoria  \
# Method Type
# PI     house                 1244000.0          780000.0
#        townhouse              760000.0               0.0
#        unit                   650000.0               0.0
# S      house                 1127000.0          675000.0
#        townhouse              828000.0               0.0
#        unit                   645750.0          492000.0
# SA     house                  932500.0          950000.0
#        townhouse              807500.0               0.0
#        unit                        0.0               0.0
# SP     house                 1050000.0          672500.0
#        townhouse              910000.0               0.0
#        unit                   515000.0          400000.0
# VB     house                 1100000.0          712500.0
#        townhouse              892500.0               0.0
#        unit                   500000.0               0.0
#
# ...

# %%
pivot = melb_df.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)

# %%
pivot.columns
# Out:
# MultiIndex([('median',     'house'),
#             ('median', 'townhouse'),
#             ('median',      'unit'),
#             (  'mean',     'house'),
#             (  'mean', 'townhouse'),
#             (  'mean',      'unit')],
#            names=[None, 'Type'])

# %%
pivot
# Out:
#                            median                          mean              \
# Type                        house townhouse   unit        house   townhouse
# Regionname
# Eastern Metropolitan        674.0     233.5  203.0   717.422847  269.440678
# Eastern Victoria            843.0       0.0  230.0  3108.960000    0.000000
# Northern Metropolitan       459.5     134.0    0.0   619.249092  317.325733
# Northern Victoria           724.0       0.0    0.0  3355.463415    0.000000
# South-Eastern Metropolitan  630.5     240.0  199.0   664.306701  212.160000
# Southern Metropolitan       586.0     246.0    0.0   569.643881  278.858824
# Western Metropolitan        531.0     198.0   62.0   507.883406  244.560669
# Western Victoria            599.5       0.0    0.0   655.500000    0.000000
#
#
# Type                              unit
# Regionname
# Eastern Metropolitan        330.444444
# Eastern Victoria            295.333333
# Northern Metropolitan       495.026538
# ...

# %%
pivot['mean']['house']
# Out:
# Regionname
# Eastern Metropolitan           717.422847
# Eastern Victoria              3108.960000
# Northern Metropolitan          619.249092
# Northern Victoria             3355.463415
# South-Eastern Metropolitan     664.306701
# Southern Metropolitan          569.643881
# Western Metropolitan           507.883406
# Western Victoria               655.500000
# Name: house, dtype: float64

# %%
pivot['mean']['house']['Eastern Metropolitan']
# Out:
# 717.4228473998295

# %%
mask = pivot['mean']['house']<pivot['median']['house']
filtereddf=pivot[mask]
display(filtereddf)
# Out:
#                       median                        mean              \
# Type                   house townhouse  unit       house   townhouse
# Regionname
# Southern Metropolitan  586.0     246.0   0.0  569.643881  278.858824
# Western Metropolitan   531.0     198.0  62.0  507.883406  244.560669
#
#
# Type                         unit
# Regionname
# Southern Metropolitan  466.380245
# Western Metropolitan   557.637232

# %%
display(list(filtereddf.index))
# Out:
# ['Southern Metropolitan', 'Western Metropolitan']

# %%
melb_df.pivot_table(
    values='BuildingArea',
    index='Type',
    columns='Rooms',
    aggfunc='median',
    fill_value=0
)
# Out:
# Rooms         1      2      3      4      5      6      7      8      10
# Type
# house      126.0  126.0  126.0  141.0  177.0  126.0  216.5  126.0  126.0
# townhouse   88.0  114.0  126.0  159.5  152.0    0.0    0.0    0.0    0.0
# unit        69.5  110.0  126.0  126.0    0.0  171.0    0.0  126.0    0.0

# %%
pivot2=melb_df.pivot_table(
    values='Price',
    index='SellerG',
    columns='Type',
    aggfunc='median',
    fill_value=0
)

# %%
pivot2
# Out:
# Type               house  townhouse      unit
# SellerG
# Alexkarbon     1036250.0   935000.0  560000.0
# Barry           830000.0   727500.0  502000.0
# Bells           692500.0   430500.0  457500.0
# Biggin         1151750.0   675000.0  548000.0
# Brad            875000.0   700000.0  465000.0
# Buckingham      830000.0   820000.0  553000.0
# Burnham         922500.0        0.0  305000.0
# Buxton         1323750.0  1030000.0  670000.0
# C21             836500.0   768750.0  625500.0
# Cayzer         1505000.0  1450000.0  707500.0
# Chisholm       1520000.0   950000.0  640000.0
# Collins        1566500.0   930000.0  592000.0
# Douglas         684000.0   500000.0  494500.0
# Eview           760000.0   597500.0  602000.0
# Fletchers      1390000.0  1238000.0  653000.0
# Gary           1370000.0   993500.0  550000.0
# Greg           1330000.0   900000.0  547500.0
# HAR             695000.0        0.0  518000.0
# Harcourts       740000.0   653750.0  500000.0
# ...
